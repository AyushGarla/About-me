# %%
# About Me
# Please fill in the following details using python.

name = "Ayush Garla"
reason = "I feel AI is the future and all other jobs involving data will be handled by AI in the upcoming future. I want to be on top of the line and shift my career to the most trending field now."
goal = "to master AI, build chatbots and gain industry level experience and work for a company to provide AI products. I love predicting data, when I work with AI I feel like I am doing something only 0.0001% of people can do."
aim = "To work on projects independently"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. my goal is: {goal}.")
# Out:
# Hi! My name is Ayush Garla. I’m excited to learn because I feel AI is the future and all other jobs involving data will be handled by AI in the upcoming future. I want to be on top of the line and shift my career to the most trending field now.. my goal is: to master AI, build chatbots and gain industry level experience and work for a company to provide AI products. I love predicting data, when I work with AI I feel like I am working on predicting the future..
